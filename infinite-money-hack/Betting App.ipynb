# %%
# CONSTANTS
TEAMS = ["PHI", "BRK", "NYK", "TOR", "BOS",
        "CHI", "CLE", "MIL", "IND", "DET",
        "MIA", "WAS", "CHO", "ATL", "ORL",
        "UTA", "DEN", "POR", "MIN", "OKC",
        "GSW", "PHO", "LAL", "SAC", "LAC",
        "DAL", "MEM", "SAS", "HOU", "NOP"]

BASE_URL = "https://www.basketball-reference.com"
BOOK_URL = "https://www.scoresandodds.com/nba/props"
YEAR = 2022
POSITIONS = ["PG", "SG", "SF", "PF", "C"]
# RELEVANT_STATS = ["player_name", "player_position", "fg3", "orb", "drb", "trb", "ast", "pts", "plus_minus"]
RELEVANT_STATS = ["player_position", "fg3", "orb", "drb", "trb", "ast", "pts"]

# %%
# %env PIP_INDEX_URL https://artifactory.service.bo1.csnzoo.com/artifactory/api/pypi/python/simple
# Out:
# env: PIP_INDEX_URL=https://artifactory.service.bo1.csnzoo.com/artifactory/api/pypi/python/simple

# %%
# %pip install beautifulsoup4
# Out:
# Looking in indexes: https://artifactory.service.bo1.csnzoo.com/artifactory/api/pypi/python/simple
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/site-packages (from beautifulsoup4) (2.3)
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
def get_url(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text)
    return soup

# %%
# - Connect to basketballreference.com
# - Retrieve schedule
# - Using schedule, find the box score for each of the games

def get_schedules():
    team_schedules = {}
    for team in TEAMS:
        game_schedule_url = f"{BASE_URL}/teams/{team}/{YEAR}_games.html"

        soup = get_url(game_schedule_url)

        # find the schedule
        past_games = []
        for game in soup.find_all("td", attrs={"data-stat":"box_score_text"}):
            if len(game["class"]) > 1:
                break

            past_games = past_games + [f"{BASE_URL}{game.a['href']}"]
        team_schedules[team] = past_games

    return team_schedules

get_schedules()
# Out:
# {'PHI': ['https://www.basketball-reference.com/boxscores/202110200NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110220PHI.html',
#   'https://www.basketball-reference.com/boxscores/202110240OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110260NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110280PHI.html',
#   'https://www.basketball-reference.com/boxscores/202110300PHI.html',
#   'https://www.basketball-reference.com/boxscores/202111010PHI.html',
#   'https://www.basketball-reference.com/boxscores/202111030PHI.html',
#   'https://www.basketball-reference.com/boxscores/202111040DET.html'],
#  'BRK': ['https://www.basketball-reference.com/boxscores/202110190MIL.html',
#   'https://www.basketball-reference.com/boxscores/202110220PHI.html',
#   'https://www.basketball-reference.com/boxscores/202110240BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110250BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110270BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110290BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110310BRK.html',
#   'https://www.basketball-reference.com/boxscores/202111030BRK.html',
#   'https://www.basketball-reference.com/boxscores/202111050DET.html'],
#  'NYK': ['https://www.basketball-reference.com/boxscores/202110200NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110220ORL.html',
#   'https://www.basketball-reference.com/boxscores/202110240NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110260NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110280CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110300NOP.html',
#   'https://www.basketball-reference.com/boxscores/202111010NYK.html',
#   'https://www.basketball-reference.com/boxscores/202111030IND.html',
#   'https://www.basketball-reference.com/boxscores/202111050MIL.html'],
#  'TOR': ['https://www.basketball-reference.com/boxscores/202110200TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110220BOS.html',
#   'https://www.basketball-reference.com/boxscores/202110230TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110250TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110270TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110290TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110300IND.html',
#   'https://www.basketball-reference.com/boxscores/202111010NYK.html',
#   'https://www.basketball-reference.com/boxscores/202111030WAS.html',
#   'https://www.basketball-reference.com/boxscores/202111050TOR.html'],
#  'BOS': ['https://www.basketball-reference.com/boxscores/202110200NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110220BOS.html',
#   'https://www.basketball-reference.com/boxscores/202110240HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110250CHO.html',
#   'https://www.basketball-reference.com/boxscores/202110270BOS.html',
#   'https://www.basketball-reference.com/boxscores/202110300WAS.html',
#   'https://www.basketball-reference.com/boxscores/202111010BOS.html',
#   'https://www.basketball-reference.com/boxscores/202111030ORL.html',
#   'https://www.basketball-reference.com/boxscores/202111040MIA.html'],
#  'CHI': ['https://www.basketball-reference.com/boxscores/202110200DET.html',
#   'https://www.basketball-reference.com/boxscores/202110220CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110230CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110250TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110280CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110300CHI.html',
#   'https://www.basketball-reference.com/boxscores/202111010BOS.html',
#   'https://www.basketball-reference.com/boxscores/202111030PHI.html'],
#  'CLE': ['https://www.basketball-reference.com/boxscores/202110200MEM.html',
#   'https://www.basketball-reference.com/boxscores/202110220CLE.html',
#   'https://www.basketball-reference.com/boxscores/202110230CLE.html',
#   'https://www.basketball-reference.com/boxscores/202110250DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110270LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110290LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110300PHO.html',
#   'https://www.basketball-reference.com/boxscores/202111010CHO.html',
#   'https://www.basketball-reference.com/boxscores/202111030CLE.html',
#   'https://www.basketball-reference.com/boxscores/202111050TOR.html'],
#  'MIL': ['https://www.basketball-reference.com/boxscores/202110190MIL.html',
#   'https://www.basketball-reference.com/boxscores/202110210MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110230SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110250IND.html',
#   'https://www.basketball-reference.com/boxscores/202110270MIL.html',
#   'https://www.basketball-reference.com/boxscores/202110300MIL.html',
#   'https://www.basketball-reference.com/boxscores/202110310MIL.html',
#   'https://www.basketball-reference.com/boxscores/202111020DET.html',
#   'https://www.basketball-reference.com/boxscores/202111050MIL.html'],
#  'IND': ['https://www.basketball-reference.com/boxscores/202110200CHO.html',
#   'https://www.basketball-reference.com/boxscores/202110220WAS.html',
#   'https://www.basketball-reference.com/boxscores/202110230IND.html',
#   'https://www.basketball-reference.com/boxscores/202110250IND.html',
#   'https://www.basketball-reference.com/boxscores/202110270TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110290BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110300IND.html',
#   'https://www.basketball-reference.com/boxscores/202111010IND.html',
#   'https://www.basketball-reference.com/boxscores/202111030IND.html',
#   'https://www.basketball-reference.com/boxscores/202111050POR.html'],
#  'DET': ['https://www.basketball-reference.com/boxscores/202110200DET.html',
#   'https://www.basketball-reference.com/boxscores/202110230CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110250ATL.html',
#   'https://www.basketball-reference.com/boxscores/202110280PHI.html',
#   'https://www.basketball-reference.com/boxscores/202110300DET.html',
#   'https://www.basketball-reference.com/boxscores/202110310BRK.html',
#   'https://www.basketball-reference.com/boxscores/202111020DET.html',
#   'https://www.basketball-reference.com/boxscores/202111040DET.html',
#   'https://www.basketball-reference.com/boxscores/202111050DET.html'],
#  'MIA': ['https://www.basketball-reference.com/boxscores/202110210MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110230IND.html',
#   'https://www.basketball-reference.com/boxscores/202110250MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110270BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110290MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110300MEM.html',
#   'https://www.basketball-reference.com/boxscores/202111020DAL.html',
#   'https://www.basketball-reference.com/boxscores/202111040MIA.html'],
#  'WAS': ['https://www.basketball-reference.com/boxscores/202110200TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110220WAS.html',
#   'https://www.basketball-reference.com/boxscores/202110250BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110270BOS.html',
#   'https://www.basketball-reference.com/boxscores/202110280WAS.html',
#   'https://www.basketball-reference.com/boxscores/202110300WAS.html',
#   'https://www.basketball-reference.com/boxscores/202111010ATL.html',
#   'https://www.basketball-reference.com/boxscores/202111030WAS.html',
#   'https://www.basketball-reference.com/boxscores/202111050WAS.html'],
#  'CHO': ['https://www.basketball-reference.com/boxscores/202110200CHO.html',
#   'https://www.basketball-reference.com/boxscores/202110220CLE.html',
#   'https://www.basketball-reference.com/boxscores/202110240BRK.html',
#   'https://www.basketball-reference.com/boxscores/202110250CHO.html',
#   'https://www.basketball-reference.com/boxscores/202110270ORL.html',
#   'https://www.basketball-reference.com/boxscores/202110290MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110310CHO.html',
#   'https://www.basketball-reference.com/boxscores/202111010CHO.html',
#   'https://www.basketball-reference.com/boxscores/202111030GSW.html',
#   'https://www.basketball-reference.com/boxscores/202111050SAC.html'],
#  'ATL': ['https://www.basketball-reference.com/boxscores/202110210ATL.html',
#   'https://www.basketball-reference.com/boxscores/202110230CLE.html',
#   'https://www.basketball-reference.com/boxscores/202110250ATL.html',
#   'https://www.basketball-reference.com/boxscores/202110270NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110280WAS.html',
#   'https://www.basketball-reference.com/boxscores/202110300PHI.html',
#   'https://www.basketball-reference.com/boxscores/202111010ATL.html',
#   'https://www.basketball-reference.com/boxscores/202111030BRK.html',
#   'https://www.basketball-reference.com/boxscores/202111040ATL.html'],
#  'ORL': ['https://www.basketball-reference.com/boxscores/202110200SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110220ORL.html',
#   'https://www.basketball-reference.com/boxscores/202110240NYK.html',
#   'https://www.basketball-reference.com/boxscores/202110250MIA.html',
#   'https://www.basketball-reference.com/boxscores/202110270ORL.html',
#   'https://www.basketball-reference.com/boxscores/202110290TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110300DET.html',
#   'https://www.basketball-reference.com/boxscores/202111010MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111030ORL.html',
#   'https://www.basketball-reference.com/boxscores/202111050ORL.html'],
#  'UTA': ['https://www.basketball-reference.com/boxscores/202110200UTA.html',
#   'https://www.basketball-reference.com/boxscores/202110220SAC.html',
#   'https://www.basketball-reference.com/boxscores/202110260UTA.html',
#   'https://www.basketball-reference.com/boxscores/202110280HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110300CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110310MIL.html',
#   'https://www.basketball-reference.com/boxscores/202111020UTA.html',
#   'https://www.basketball-reference.com/boxscores/202111040ATL.html'],
#  'DEN': ['https://www.basketball-reference.com/boxscores/202110200PHO.html',
#   'https://www.basketball-reference.com/boxscores/202110220DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110250DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110260UTA.html',
#   'https://www.basketball-reference.com/boxscores/202110290DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110300MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111010MEM.html',
#   'https://www.basketball-reference.com/boxscores/202111030MEM.html'],
#  'POR': ['https://www.basketball-reference.com/boxscores/202110200POR.html',
#   'https://www.basketball-reference.com/boxscores/202110230POR.html',
#   'https://www.basketball-reference.com/boxscores/202110250LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110270POR.html',
#   'https://www.basketball-reference.com/boxscores/202110290POR.html',
#   'https://www.basketball-reference.com/boxscores/202110310CHO.html',
#   'https://www.basketball-reference.com/boxscores/202111010PHI.html',
#   'https://www.basketball-reference.com/boxscores/202111030CLE.html',
#   'https://www.basketball-reference.com/boxscores/202111050POR.html'],
#  'MIN': ['https://www.basketball-reference.com/boxscores/202110200MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110230MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110250MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110270MIL.html',
#   'https://www.basketball-reference.com/boxscores/202110300MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111010MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111030MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111050MIN.html'],
#  'OKC': ['https://www.basketball-reference.com/boxscores/202110200UTA.html',
#   'https://www.basketball-reference.com/boxscores/202110220HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110240OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110260OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110270OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110300GSW.html',
#   'https://www.basketball-reference.com/boxscores/202111010LAC.html',
#   'https://www.basketball-reference.com/boxscores/202111040LAL.html'],
#  'GSW': ['https://www.basketball-reference.com/boxscores/202110190LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110210GSW.html',
#   'https://www.basketball-reference.com/boxscores/202110240SAC.html',
#   'https://www.basketball-reference.com/boxscores/202110260OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110280GSW.html',
#   'https://www.basketball-reference.com/boxscores/202110300GSW.html',
#   'https://www.basketball-reference.com/boxscores/202111030GSW.html',
#   'https://www.basketball-reference.com/boxscores/202111050GSW.html'],
#  'PHO': ['https://www.basketball-reference.com/boxscores/202110200PHO.html',
#   'https://www.basketball-reference.com/boxscores/202110220LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110230POR.html',
#   'https://www.basketball-reference.com/boxscores/202110270PHO.html',
#   'https://www.basketball-reference.com/boxscores/202110300PHO.html',
#   'https://www.basketball-reference.com/boxscores/202111020PHO.html',
#   'https://www.basketball-reference.com/boxscores/202111040PHO.html'],
#  'LAL': ['https://www.basketball-reference.com/boxscores/202110190LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110220LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110240LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110260SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110270OKC.html',
#   'https://www.basketball-reference.com/boxscores/202110290LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110310LAL.html',
#   'https://www.basketball-reference.com/boxscores/202111020LAL.html',
#   'https://www.basketball-reference.com/boxscores/202111040LAL.html'],
#  'SAC': ['https://www.basketball-reference.com/boxscores/202110200POR.html',
#   'https://www.basketball-reference.com/boxscores/202110220SAC.html',
#   'https://www.basketball-reference.com/boxscores/202110240SAC.html',
#   'https://www.basketball-reference.com/boxscores/202110270PHO.html',
#   'https://www.basketball-reference.com/boxscores/202110290NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110310DAL.html',
#   'https://www.basketball-reference.com/boxscores/202111020UTA.html',
#   'https://www.basketball-reference.com/boxscores/202111030SAC.html',
#   'https://www.basketball-reference.com/boxscores/202111050SAC.html'],
#  'LAC': ['https://www.basketball-reference.com/boxscores/202110210GSW.html',
#   'https://www.basketball-reference.com/boxscores/202110230LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110250LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110270LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110290POR.html',
#   'https://www.basketball-reference.com/boxscores/202111010LAC.html',
#   'https://www.basketball-reference.com/boxscores/202111030MIN.html',
#   'https://www.basketball-reference.com/boxscores/202111050MIN.html'],
#  'DAL': ['https://www.basketball-reference.com/boxscores/202110210ATL.html',
#   'https://www.basketball-reference.com/boxscores/202110230TOR.html',
#   'https://www.basketball-reference.com/boxscores/202110260DAL.html',
#   'https://www.basketball-reference.com/boxscores/202110280DAL.html',
#   'https://www.basketball-reference.com/boxscores/202110290DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110310DAL.html',
#   'https://www.basketball-reference.com/boxscores/202111020DAL.html',
#   'https://www.basketball-reference.com/boxscores/202111030SAS.html'],
#  'MEM': ['https://www.basketball-reference.com/boxscores/202110200MEM.html',
#   'https://www.basketball-reference.com/boxscores/202110230LAC.html',
#   'https://www.basketball-reference.com/boxscores/202110240LAL.html',
#   'https://www.basketball-reference.com/boxscores/202110270POR.html',
#   'https://www.basketball-reference.com/boxscores/202110280GSW.html',
#   'https://www.basketball-reference.com/boxscores/202110300MEM.html',
#   'https://www.basketball-reference.com/boxscores/202111010MEM.html',
#   'https://www.basketball-reference.com/boxscores/202111030MEM.html',
#   'https://www.basketball-reference.com/boxscores/202111050WAS.html'],
#  'SAS': ['https://www.basketball-reference.com/boxscores/202110200SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110220DEN.html',
#   'https://www.basketball-reference.com/boxscores/202110230SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110260SAS.html',
#   'https://www.basketball-reference.com/boxscores/202110280DAL.html',
#   'https://www.basketball-reference.com/boxscores/202110300MIL.html',
#   'https://www.basketball-reference.com/boxscores/202111010IND.html',
#   'https://www.basketball-reference.com/boxscores/202111030SAS.html',
#   'https://www.basketball-reference.com/boxscores/202111050ORL.html'],
#  'HOU': ['https://www.basketball-reference.com/boxscores/202110200MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110220HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110240HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110260DAL.html',
#   'https://www.basketball-reference.com/boxscores/202110280HOU.html',
#   'https://www.basketball-reference.com/boxscores/202110310LAL.html',
#   'https://www.basketball-reference.com/boxscores/202111020LAL.html',
#   'https://www.basketball-reference.com/boxscores/202111040PHO.html'],
#  'NOP': ['https://www.basketball-reference.com/boxscores/202110200NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110220CHI.html',
#   'https://www.basketball-reference.com/boxscores/202110230MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110250MIN.html',
#   'https://www.basketball-reference.com/boxscores/202110270NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110290NOP.html',
#   'https://www.basketball-reference.com/boxscores/202110300NOP.html',
#   'https://www.basketball-reference.com/boxscores/202111020PHO.html',
#   'https://www.basketball-reference.com/boxscores/202111030SAC.html',
#   'https://www.basketball-reference.com/boxscores/202111050GSW.html']}

# %%
def get_player_position(player_page):
    soup = get_url(player_page)

    player_stats = {}
    for el in soup.find("tr", attrs={"id":"per_game.2022"}):
        if el["data-stat"] == "pos":
            return el.text

get_player_position("https://www.basketball-reference.com/players/h/hardeja01.html")
# Out:
# 'PG'

# %%
def get_player_stats(player_page):
    soup = get_url(player_page)

    player_stats = {}
    for el in soup.find("tr", attrs={"id":"per_game.2022"}):
        if el["class"][0] == "right":
            player_stats[el["data-stat"]] = el.text
        
    return player_stats

get_player_stats("https://www.basketball-reference.com/players/h/hardeja01.html")
# Out:
# {'g': '9',
#  'gs': '9',
#  'mp_per_g': '33.9',
#  'fg_per_g': '5.2',
#  'fga_per_g': '13.6',
#  'fg_pct': '.385',
#  'fg3_per_g': '3.1',
#  'fg3a_per_g': '7.6',
#  'fg3_pct': '.412',
#  'fg2_per_g': '2.1',
#  'fg2a_per_g': '6.0',
#  'fg2_pct': '.352',
#  'efg_pct': '.500',
#  'ft_per_g': '4.1',
#  'fta_per_g': '4.7',
#  'ft_pct': '.881',
#  'orb_per_g': '0.9',
#  'drb_per_g': '6.6',
#  'trb_per_g': '7.4',
#  'ast_per_g': '9.0',
#  'stl_per_g': '1.1',
#  'blk_per_g': '1.0',
#  'tov_per_g': '4.9',
#  'pf_per_g': '2.3',
#  'pts_per_g': '17.7'}

# %% [markdown]
# # Version 1 - Average Statistic For Each Position Scored Against Each Team

# %%
# - Collect statistics for starters based on the position
#     - Might need to classify positions of players first / lookup
#     - These should include current season performance, and performance in the last X games
# - Collect average statistics of starters for each team
#     - These should include last seasons performance, current season performance, and performance in the last X games

def get_game_stats(gaame):
    soup = get_url(game)

    home_stats = []
    away_stats = []
    flag = True
    for div in soup.find_all("div", class_="table_container"):
        try:
            # Each team (HOME first)
            if "game-basic" in div["id"]:
#                 print(div["id"])

                # Each starter
                for player in div.tbody.find_all("tr")[:5]:
                    player_stats = {}

                    player_stats["player_name"] = player.th.a.text

                    player_page = BASE_URL + player.th.a["href"]

                    # Calculations using the players primary position
                    player_stats["player_position"] = get_player_position(player_page)

                    for stat in player.find_all("td"):
                        player_stats[stat["data-stat"]] = stat.text

                    if flag:
                        home_stats = home_stats + [player_stats]
                    else:
                        away_stats = away_stats + [player_stats]

                flag = False
        except KeyError as e:
            continue
    
    return home_stats, away_stats

# %%
schedules = get_schedules()
all_stats_against = {team: {pos: {stat: 0 for stat in RELEVANT_STATS[1:]} for pos in POSITIONS} for team in TEAMS}

for team in schedules.keys():
    print(f"working on team: {team}")

    for game in schedules[team]:
        stats_against_team = {}
        home_stats, away_stats = get_game_stats(game)
        
        for player_stats in away_stats:
            player_stats = {stat:player_stats[stat] for stat in RELEVANT_STATS}
            
            for stat in [*player_stats][1:]:
                all_stats_against[team][player_stats["player_position"]][stat] += int(player_stats[stat])

# %%
all_stats_against
# Out:
# {'PHI': {'PG': {'fg3': 17,
#    'orb': 6,
#    'drb': 28,
#    'trb': 34,
#    'ast': 48,
#    'pts': 165},
#   'SG': {'fg3': 28, 'orb': 4, 'drb': 42, 'trb': 46, 'ast': 28, 'pts': 189},
#   'SF': {'fg3': 12, 'orb': 5, 'drb': 29, 'trb': 34, 'ast': 20, 'pts': 83},
#   'PF': {'fg3': 10, 'orb': 5, 'drb': 43, 'trb': 48, 'ast': 22, 'pts': 113},
#   'C': {'fg3': 6, 'orb': 22, 'drb': 63, 'trb': 85, 'ast': 30, 'pts': 128}},
#  'BRK': {'PG': {'fg3': 25,
#    'orb': 5,
#    'drb': 46,
#    'trb': 51,
#    'ast': 61,
#    'pts': 153},
#   'SG': {'fg3': 7, 'orb': 0, 'drb': 8, 'trb': 8, 'ast': 6, 'pts': 33},
#   'SF': {'fg3': 25, 'orb': 7, 'drb': 54, 'trb': 61, 'ast': 15, 'pts': 163},
#   'PF': {'fg3': 17, 'orb': 13, 'drb': 83, 'trb': 96, 'ast': 50, 'pts': 251},
#   'C': {'fg3': 4, 'orb': 6, 'drb': 20, 'trb': 26, 'ast': 5, 'pts': 40}},
#  'NYK': {'PG': {'fg3': 18,
#    'orb': 6,
#    'drb': 34,
#    'trb': 40,
#    'ast': 47,
#    'pts': 118},
#   'SG': {'fg3': 31, 'orb': 10, 'drb': 31, 'trb': 41, 'ast': 32, 'pts': 172},
#   'SF': {'fg3': 18, 'orb': 4, 'drb': 36, 'trb': 40, 'ast': 17, 'pts': 124},
#   'PF': {'fg3': 13, 'orb': 10, 'drb': 43, 'trb': 53, 'ast': 28, 'pts': 134},
#   'C': {'fg3': 15, 'orb': 28, 'drb': 83, 'trb': 111, 'ast': 33, 'pts': 155}},
#  'TOR': {'PG': {'fg3': 23,
#    'orb': 8,
#    'drb': 34,
#    'trb': 42,
#    'ast': 66,
#    'pts': 152},
#   'SG': {'fg3': 19, 'orb': 11, 'drb': 33, 'trb': 44, 'ast': 23, 'pts': 150},
#   'SF': {'fg3': 27, 'orb': 10, 'drb': 42, 'trb': 52, 'ast': 21, 'pts': 174},
#   'PF': {'fg3': 5, 'orb': 19, 'drb': 38, 'trb': 57, 'ast': 21, 'pts': 119},
#   'C': {'fg3': 4, 'orb': 31, 'drb': 77, 'trb': 108, 'ast': 19, 'pts': 117}},
#  'BOS': {'PG': {'fg3': 23,
#    'orb': 3,
#    'drb': 40,
#    'trb': 43,
#    'ast': 38,
#    'pts': 122},
#   'SG': {'fg3': 22, 'orb': 2, 'drb': 21, 'trb': 23, 'ast': 16, 'pts': 116},
#   'SF': {'fg3': 21, 'orb': 12, 'drb': 55, 'trb': 67, 'ast': 26, 'pts': 205},
#   'PF': {'fg3': 8, 'orb': 10, 'drb': 32, 'trb': 42, 'ast': 16, 'pts': 80},
#   'C': {'fg3': 11, 'orb': 38, 'drb': 102, 'trb': 140, 'ast': 30, 'pts': 175}},
#  'CHI': {'PG': {'fg3': 13,
#    'orb': 6,
#    'drb': 34,
#    'trb': 40,
#    'ast': 43,
#    'pts': 99},
#   'SG': {'fg3': 20, 'orb': 7, 'drb': 34, 'trb': 41, 'ast': 24, 'pts': 161},
#   'SF': {'fg3': 11, 'orb': 10, 'drb': 39, 'trb': 49, 'ast': 33, 'pts': 182},
#   'PF': {'fg3': 6, 'orb': 5, 'drb': 15, 'trb': 20, 'ast': 3, 'pts': 60},
#   'C': {'fg3': 12, 'orb': 14, 'drb': 72, 'trb': 86, 'ast': 28, 'pts': 130}},
#  'CLE': {'PG': {'fg3': 24,
#    'orb': 8,
#    'drb': 34,
#    'trb': 42,
#    'ast': 70,
#    'pts': 185},
#   'SG': {'fg3': 19, 'orb': 11, 'drb': 19, 'trb': 30, 'ast': 27, 'pts': 181},
#   'SF': {'fg3': 11, 'orb': 6, 'drb': 31, 'trb': 37, 'ast': 27, 'pts': 114},
#   'PF': {'fg3': 14, 'orb': 21, 'drb': 66, 'trb': 87, 'ast': 28, 'pts': 147},
#   'C': {'fg3': 2, 'orb': 28, 'drb': 87, 'trb': 115, 'ast': 21, 'pts': 132}},
#  'MIL': {'PG': {'fg3': 7,
#    'orb': 1,
#    'drb': 19,
#    'trb': 20,
#    'ast': 28,
#    'pts': 66},
#   'SG': {'fg3': 34, 'orb': 11, 'drb': 50, 'trb': 61, 'ast': 36, 'pts': 167},
#   'SF': {'fg3': 8, 'orb': 15, 'drb': 40, 'trb': 55, 'ast': 33, 'pts': 126},
#   'PF': {'fg3': 22, 'orb': 13, 'drb': 56, 'trb': 69, 'ast': 32, 'pts': 204},
#   'C': {'fg3': 3, 'orb': 20, 'drb': 31, 'trb': 51, 'ast': 13, 'pts': 69}},
#  'IND': {'PG': {'fg3': 25,
#    'orb': 16,
#    'drb': 55,
#    'trb': 71,
#    'ast': 78,
#    'pts': 207},
#   'SG': {'fg3': 25, 'orb': 5, 'drb': 35, 'trb': 40, 'ast': 35, 'pts': 175},
#   'SF': {'fg3': 17, 'orb': 3, 'drb': 26, 'trb': 29, 'ast': 13, 'pts': 127},
#   'PF': {'fg3': 12, 'orb': 7, 'drb': 38, 'trb': 45, 'ast': 20, 'pts': 101},
#   'C': {'fg3': 12, 'orb': 33, 'drb': 93, 'trb': 126, 'ast': 36, 'pts': 193}},
#  'DET': {'PG': {'fg3': 21,
#    'orb': 10,
#    'drb': 52,
#    'trb': 62,
#    'ast': 50,
#    'pts': 150},
#   'SG': {'fg3': 8, 'orb': 1, 'drb': 12, 'trb': 13, 'ast': 10, 'pts': 54},
#   'SF': {'fg3': 8, 'orb': 16, 'drb': 31, 'trb': 47, 'ast': 26, 'pts': 91},
#   'PF': {'fg3': 15, 'orb': 7, 'drb': 41, 'trb': 48, 'ast': 27, 'pts': 178},
#   'C': {'fg3': 2, 'orb': 18, 'drb': 67, 'trb': 85, 'ast': 8, 'pts': 91}},
#  'MIA': {'PG': {'fg3': 13,
#    'orb': 9,
#    'drb': 42,
#    'trb': 51,
#    'ast': 50,
#    'pts': 134},
#   'SG': {'fg3': 21, 'orb': 3, 'drb': 26, 'trb': 29, 'ast': 15, 'pts': 100},
#   'SF': {'fg3': 14, 'orb': 11, 'drb': 25, 'trb': 36, 'ast': 20, 'pts': 160},
#   'PF': {'fg3': 8, 'orb': 11, 'drb': 32, 'trb': 43, 'ast': 11, 'pts': 60},
#   'C': {'fg3': 0, 'orb': 19, 'drb': 62, 'trb': 81, 'ast': 17, 'pts': 108}},
#  'WAS': {'PG': {'fg3': 18,
#    'orb': 8,
#    'drb': 33,
#    'trb': 41,
#    'ast': 54,
#    'pts': 160},
#   'SG': {'fg3': 21, 'orb': 9, 'drb': 50, 'trb': 59, 'ast': 45, 'pts': 171},
#   'SF': {'fg3': 8, 'orb': 7, 'drb': 27, 'trb': 34, 'ast': 6, 'pts': 83},
#   'PF': {'fg3': 13, 'orb': 13, 'drb': 66, 'trb': 79, 'ast': 18, 'pts': 130},
#   'C': {'fg3': 3, 'orb': 31, 'drb': 47, 'trb': 78, 'ast': 18, 'pts': 128}},
#  'CHO': {'PG': {'fg3': 34,
#    'orb': 12,
#    'drb': 56,
#    'trb': 68,
#    'ast': 81,
#    'pts': 218},
#   'SG': {'fg3': 21, 'orb': 3, 'drb': 18, 'trb': 21, 'ast': 15, 'pts': 125},
#   'SF': {'fg3': 25, 'orb': 13, 'drb': 43, 'trb': 56, 'ast': 21, 'pts': 171},
#   'PF': {'fg3': 13, 'orb': 12, 'drb': 62, 'trb': 74, 'ast': 43, 'pts': 155},
#   'C': {'fg3': 4, 'orb': 31, 'drb': 76, 'trb': 107, 'ast': 25, 'pts': 132}},
#  'ATL': {'PG': {'fg3': 20,
#    'orb': 3,
#    'drb': 26,
#    'trb': 29,
#    'ast': 68,
#    'pts': 181},
#   'SG': {'fg3': 21, 'orb': 5, 'drb': 33, 'trb': 38, 'ast': 34, 'pts': 144},
#   'SF': {'fg3': 13, 'orb': 3, 'drb': 24, 'trb': 27, 'ast': 11, 'pts': 90},
#   'PF': {'fg3': 15, 'orb': 14, 'drb': 65, 'trb': 79, 'ast': 29, 'pts': 174},
#   'C': {'fg3': 2, 'orb': 22, 'drb': 69, 'trb': 91, 'ast': 14, 'pts': 124}},
#  'ORL': {'PG': {'fg3': 20,
#    'orb': 11,
#    'drb': 48,
#    'trb': 59,
#    'ast': 72,
#    'pts': 173},
#   'SG': {'fg3': 11, 'orb': 2, 'drb': 21, 'trb': 23, 'ast': 13, 'pts': 77},
#   'SF': {'fg3': 15, 'orb': 8, 'drb': 26, 'trb': 34, 'ast': 17, 'pts': 139},
#   'PF': {'fg3': 7, 'orb': 12, 'drb': 31, 'trb': 43, 'ast': 10, 'pts': 100},
#   'C': {'fg3': 18, 'orb': 42, 'drb': 105, 'trb': 147, 'ast': 33, 'pts': 182}},
#  'UTA': {'PG': {'fg3': 13,
#    'orb': 6,
#    'drb': 13,
#    'trb': 19,
#    'ast': 27,
#    'pts': 104},
#   'SG': {'fg3': 19, 'orb': 16, 'drb': 35, 'trb': 51, 'ast': 35, 'pts': 181},
#   'SF': {'fg3': 2, 'orb': 11, 'drb': 25, 'trb': 36, 'ast': 15, 'pts': 70},
#   'PF': {'fg3': 13, 'orb': 10, 'drb': 23, 'trb': 33, 'ast': 11, 'pts': 120},
#   'C': {'fg3': 4, 'orb': 18, 'drb': 81, 'trb': 99, 'ast': 8, 'pts': 109}},
#  'DEN': {'PG': {'fg3': 9,
#    'orb': 5,
#    'drb': 20,
#    'trb': 25,
#    'ast': 45,
#    'pts': 111},
#   'SG': {'fg3': 11, 'orb': 8, 'drb': 32, 'trb': 40, 'ast': 28, 'pts': 108},
#   'SF': {'fg3': 12, 'orb': 5, 'drb': 20, 'trb': 25, 'ast': 11, 'pts': 78},
#   'PF': {'fg3': 11, 'orb': 10, 'drb': 41, 'trb': 51, 'ast': 9, 'pts': 91},
#   'C': {'fg3': 7, 'orb': 20, 'drb': 76, 'trb': 96, 'ast': 28, 'pts': 133}},
#  'POR': {'PG': {'fg3': 20,
#    'orb': 2,
#    'drb': 33,
#    'trb': 35,
#    'ast': 77,
#    'pts': 151},
#   'SG': {'fg3': 38, 'orb': 5, 'drb': 34, 'trb': 39, 'ast': 36, 'pts': 219},
#   'SF': {'fg3': 17, 'orb': 3, 'drb': 23, 'trb': 26, 'ast': 9, 'pts': 113},
#   'PF': {'fg3': 17, 'orb': 4, 'drb': 49, 'trb': 53, 'ast': 12, 'pts': 84},
#   'C': {'fg3': 1, 'orb': 24, 'drb': 82, 'trb': 106, 'ast': 27, 'pts': 122}},
#  'MIN': {'PG': {'fg3': 11,
#    'orb': 7,
#    'drb': 25,
#    'trb': 32,
#    'ast': 32,
#    'pts': 75},
#   'SG': {'fg3': 29, 'orb': 19, 'drb': 47, 'trb': 66, 'ast': 33, 'pts': 205},
#   'SF': {'fg3': 1, 'orb': 2, 'drb': 3, 'trb': 5, 'ast': 5, 'pts': 16},
#   'PF': {'fg3': 8, 'orb': 17, 'drb': 41, 'trb': 58, 'ast': 14, 'pts': 89},
#   'C': {'fg3': 22, 'orb': 25, 'drb': 46, 'trb': 71, 'ast': 23, 'pts': 162}},
#  'OKC': {'PG': {'fg3': 25,
#    'orb': 3,
#    'drb': 30,
#    'trb': 33,
#    'ast': 45,
#    'pts': 166},
#   'SG': {'fg3': 13, 'orb': 7, 'drb': 27, 'trb': 34, 'ast': 34, 'pts': 107},
#   'SF': {'fg3': 14, 'orb': 7, 'drb': 40, 'trb': 47, 'ast': 23, 'pts': 105},
#   'PF': {'fg3': 11, 'orb': 6, 'drb': 35, 'trb': 41, 'ast': 16, 'pts': 85},
#   'C': {'fg3': 6, 'orb': 31, 'drb': 57, 'trb': 88, 'ast': 9, 'pts': 123}},
#  'GSW': {'PG': {'fg3': 34,
#    'orb': 5,
#    'drb': 39,
#    'trb': 44,
#    'ast': 44,
#    'pts': 190},
#   'SG': {'fg3': 19, 'orb': 5, 'drb': 23, 'trb': 28, 'ast': 26, 'pts': 104},
#   'SF': {'fg3': 21, 'orb': 9, 'drb': 32, 'trb': 41, 'ast': 17, 'pts': 138},
#   'PF': {'fg3': 6, 'orb': 10, 'drb': 49, 'trb': 59, 'ast': 37, 'pts': 72},
#   'C': {'fg3': 3, 'orb': 15, 'drb': 41, 'trb': 56, 'ast': 9, 'pts': 87}},
#  'PHO': {'PG': {'fg3': 7,
#    'orb': 7,
#    'drb': 29,
#    'trb': 36,
#    'ast': 76,
#    'pts': 94},
#   'SG': {'fg3': 16, 'orb': 7, 'drb': 27, 'trb': 34, 'ast': 30, 'pts': 143},
#   'SF': {'fg3': 15, 'orb': 3, 'drb': 22, 'trb': 25, 'ast': 11, 'pts': 124},
#   'PF': {'fg3': 10, 'orb': 2, 'drb': 32, 'trb': 34, 'ast': 12, 'pts': 40},
#   'C': {'fg3': 1, 'orb': 22, 'drb': 63, 'trb': 85, 'ast': 11, 'pts': 120}},
#  'LAL': {'PG': {'fg3': 14,
#    'orb': 16,
#    'drb': 57,
#    'trb': 73,
#    'ast': 72,
#    'pts': 177},
#   'SG': {'fg3': 4, 'orb': 2, 'drb': 14, 'trb': 16, 'ast': 19, 'pts': 38},
#   'SF': {'fg3': 26, 'orb': 7, 'drb': 53, 'trb': 60, 'ast': 50, 'pts': 222},
#   'PF': {'fg3': 4, 'orb': 2, 'drb': 5, 'trb': 7, 'ast': 2, 'pts': 24},
#   'C': {'fg3': 3, 'orb': 44, 'drb': 82, 'trb': 126, 'ast': 23, 'pts': 223}},
#  'SAC': {'PG': {'fg3': 14,
#    'orb': 8,
#    'drb': 31,
#    'trb': 39,
#    'ast': 58,
#    'pts': 164},
#   'SG': {'fg3': 23, 'orb': 13, 'drb': 34, 'trb': 47, 'ast': 51, 'pts': 191},
#   'SF': {'fg3': 10, 'orb': 4, 'drb': 29, 'trb': 33, 'ast': 12, 'pts': 74},
#   'PF': {'fg3': 21, 'orb': 12, 'drb': 48, 'trb': 60, 'ast': 12, 'pts': 144},
#   'C': {'fg3': 3, 'orb': 29, 'drb': 95, 'trb': 124, 'ast': 12, 'pts': 158}},
#  'LAC': {'PG': {'fg3': 15,
#    'orb': 13,
#    'drb': 32,
#    'trb': 45,
#    'ast': 38,
#    'pts': 115},
#   'SG': {'fg3': 22, 'orb': 7, 'drb': 16, 'trb': 23, 'ast': 25, 'pts': 145},
#   'SF': {'fg3': 19, 'orb': 3, 'drb': 35, 'trb': 38, 'ast': 21, 'pts': 128},
#   'PF': {'fg3': 14, 'orb': 6, 'drb': 36, 'trb': 42, 'ast': 16, 'pts': 75},
#   'C': {'fg3': 6, 'orb': 23, 'drb': 45, 'trb': 68, 'ast': 15, 'pts': 88}},
#  'DAL': {'PG': {'fg3': 16,
#    'orb': 5,
#    'drb': 47,
#    'trb': 52,
#    'ast': 60,
#    'pts': 202},
#   'SG': {'fg3': 19, 'orb': 3, 'drb': 25, 'trb': 28, 'ast': 20, 'pts': 114},
#   'SF': {'fg3': 9, 'orb': 1, 'drb': 17, 'trb': 18, 'ast': 3, 'pts': 69},
#   'PF': {'fg3': 11, 'orb': 17, 'drb': 39, 'trb': 56, 'ast': 12, 'pts': 105},
#   'C': {'fg3': 2, 'orb': 15, 'drb': 54, 'trb': 69, 'ast': 17, 'pts': 79}},
#  'MEM': {'PG': {'fg3': 18,
#    'orb': 13,
#    'drb': 37,
#    'trb': 50,
#    'ast': 71,
#    'pts': 194},
#   'SG': {'fg3': 22, 'orb': 6, 'drb': 29, 'trb': 35, 'ast': 29, 'pts': 139},
#   'SF': {'fg3': 23, 'orb': 5, 'drb': 35, 'trb': 40, 'ast': 21, 'pts': 162},
#   'PF': {'fg3': 16, 'orb': 2, 'drb': 41, 'trb': 43, 'ast': 16, 'pts': 83},
#   'C': {'fg3': 1, 'orb': 24, 'drb': 49, 'trb': 73, 'ast': 18, 'pts': 100}},
#  'SAS': {'PG': {'fg3': 13,
#    'orb': 4,
#    'drb': 50,
#    'trb': 54,
#    'ast': 63,
#    'pts': 150},
#   'SG': {'fg3': 20, 'orb': 6, 'drb': 35, 'trb': 41, 'ast': 43, 'pts': 130},
#   'SF': {'fg3': 6, 'orb': 7, 'drb': 30, 'trb': 37, 'ast': 17, 'pts': 102},
#   'PF': {'fg3': 12, 'orb': 5, 'drb': 27, 'trb': 32, 'ast': 8, 'pts': 93},
#   'C': {'fg3': 6, 'orb': 36, 'drb': 61, 'trb': 97, 'ast': 29, 'pts': 170}},
#  'HOU': {'PG': {'fg3': 16,
#    'orb': 9,
#    'drb': 38,
#    'trb': 47,
#    'ast': 58,
#    'pts': 142},
#   'SG': {'fg3': 21, 'orb': 8, 'drb': 30, 'trb': 38, 'ast': 18, 'pts': 134},
#   'SF': {'fg3': 10, 'orb': 10, 'drb': 37, 'trb': 47, 'ast': 30, 'pts': 112},
#   'PF': {'fg3': 2, 'orb': 5, 'drb': 11, 'trb': 16, 'ast': 4, 'pts': 22},
#   'C': {'fg3': 11, 'orb': 26, 'drb': 62, 'trb': 88, 'ast': 13, 'pts': 179}},
#  'NOP': {'PG': {'fg3': 28,
#    'orb': 5,
#    'drb': 38,
#    'trb': 43,
#    'ast': 66,
#    'pts': 162},
#   'SG': {'fg3': 30, 'orb': 12, 'drb': 47, 'trb': 59, 'ast': 40, 'pts': 197},
#   'SF': {'fg3': 12, 'orb': 5, 'drb': 41, 'trb': 46, 'ast': 25, 'pts': 155},
#   'PF': {'fg3': 10, 'orb': 10, 'drb': 26, 'trb': 36, 'ast': 13, 'pts': 59},
#   'C': {'fg3': 12, 'orb': 33, 'drb': 62, 'trb': 95, 'ast': 32, 'pts': 205}}}

# %%
all_stats_df = pd.DataFrame.from_dict(all_stats_against, orient="index")
# all_stats_df['pra'] = all_stats_df['trb'] + all_stats_df['ast'] + all_stats_df['pts']
all_stats_df
# Out:
#                                                     PG  \
# PHI  {'fg3': 17, 'orb': 6, 'drb': 28, 'trb': 34, 'a...
# BRK  {'fg3': 25, 'orb': 5, 'drb': 46, 'trb': 51, 'a...
# NYK  {'fg3': 18, 'orb': 6, 'drb': 34, 'trb': 40, 'a...
# TOR  {'fg3': 23, 'orb': 8, 'drb': 34, 'trb': 42, 'a...
# BOS  {'fg3': 23, 'orb': 3, 'drb': 40, 'trb': 43, 'a...
# CHI  {'fg3': 13, 'orb': 6, 'drb': 34, 'trb': 40, 'a...
# CLE  {'fg3': 24, 'orb': 8, 'drb': 34, 'trb': 42, 'a...
# MIL  {'fg3': 7, 'orb': 1, 'drb': 19, 'trb': 20, 'as...
# IND  {'fg3': 25, 'orb': 16, 'drb': 55, 'trb': 71, '...
# DET  {'fg3': 21, 'orb': 10, 'drb': 52, 'trb': 62, '...
# MIA  {'fg3': 13, 'orb': 9, 'drb': 42, 'trb': 51, 'a...
# WAS  {'fg3': 18, 'orb': 8, 'drb': 33, 'trb': 41, 'a...
# CHO  {'fg3': 34, 'orb': 12, 'drb': 56, 'trb': 68, '...
# ATL  {'fg3': 20, 'orb': 3, 'drb': 26, 'trb': 29, 'a...
# ORL  {'fg3': 20, 'orb': 11, 'drb': 48, 'trb': 59, '...
# UTA  {'fg3': 13, 'orb': 6, 'drb': 13, 'trb': 19, 'a...
# DEN  {'fg3': 9, 'orb': 5, 'drb': 20, 'trb': 25, 'as...
# POR  {'fg3': 20, 'orb': 2, 'drb': 33, 'trb': 35, 'a...
# MIN  {'fg3': 11, 'orb': 7, 'drb': 25, 'trb': 32, 'a...
# OKC  {'fg3': 25, 'orb': 3, 'drb': 30, 'trb': 33, 'a...
# GSW  {'fg3': 34, 'orb': 5, 'drb': 39, 'trb': 44, 'a...
# PHO  {'fg3': 7, 'orb': 7, 'drb': 29, 'trb': 36, 'as...
# LAL  {'fg3': 14, 'orb': 16, 'drb': 57, 'trb': 73, '...
# SAC  {'fg3': 14, 'orb': 8, 'drb': 31, 'trb': 39, 'a...
# LAC  {'fg3': 15, 'orb': 13, 'drb': 32, 'trb': 45, '...
# DAL  {'fg3': 16, 'orb': 5, 'drb': 47, 'trb': 52, 'a...
# MEM  {'fg3': 18, 'orb': 13, 'drb': 37, 'trb': 50, '...
# SAS  {'fg3': 13, 'orb': 4, 'drb': 50, 'trb': 54, 'a...
# HOU  {'fg3': 16, 'orb': 9, 'drb': 38, 'trb': 47, 'a...
# NOP  {'fg3': 28, 'orb': 5, 'drb': 38, 'trb': 43, 'a...
#
#                                                     SG  \
# PHI  {'fg3': 28, 'orb': 4, 'drb': 42, 'trb': 46, 'a...
# BRK  {'fg3': 7, 'orb': 0, 'drb': 8, 'trb': 8, 'ast'...
# NYK  {'fg3': 31, 'orb': 10, 'drb': 31, 'trb': 41, '...
# TOR  {'fg3': 19, 'orb': 11, 'drb': 33, 'trb': 44, '...
# BOS  {'fg3': 22, 'orb': 2, 'drb': 21, 'trb': 23, 'a...
# CHI  {'fg3': 20, 'orb': 7, 'drb': 34, 'trb': 41, 'a...
# CLE  {'fg3': 19, 'orb': 11, 'drb': 19, 'trb': 30, '...
# MIL  {'fg3': 34, 'orb': 11, 'drb': 50, 'trb': 61, '...
# IND  {'fg3': 25, 'orb': 5, 'drb': 35, 'trb': 40, 'a...
# DET  {'fg3': 8, 'orb': 1, 'drb': 12, 'trb': 13, 'as...
# MIA  {'fg3': 21, 'orb': 3, 'drb': 26, 'trb': 29, 'a...
# WAS  {'fg3': 21, 'orb': 9, 'drb': 50, 'trb': 59, 'a...
# CHO  {'fg3': 21, 'orb': 3, 'drb': 18, 'trb': 21, 'a...
# ATL  {'fg3': 21, 'orb': 5, 'drb': 33, 'trb': 38, 'a...
# ORL  {'fg3': 11, 'orb': 2, 'drb': 21, 'trb': 23, 'a...
# UTA  {'fg3': 19, 'orb': 16, 'drb': 35, 'trb': 51, '...
# DEN  {'fg3': 11, 'orb': 8, 'drb': 32, 'trb': 40, 'a...
# POR  {'fg3': 38, 'orb': 5, 'drb': 34, 'trb': 39, 'a...
# MIN  {'fg3': 29, 'orb': 19, 'drb': 47, 'trb': 66, '...
# OKC  {'fg3': 13, 'orb': 7, 'drb': 27, 'trb': 34, 'a...
# GSW  {'fg3': 19, 'orb': 5, 'drb': 23, 'trb': 28, 'a...
# PHO  {'fg3': 16, 'orb': 7, 'drb': 27, 'trb': 34, 'a...
# LAL  {'fg3': 4, 'orb': 2, 'drb': 14, 'trb': 16, 'as...
# SAC  {'fg3': 23, 'orb': 13, 'drb': 34, 'trb': 47, '...
# LAC  {'fg3': 22, 'orb': 7, 'drb': 16, 'trb': 23, 'a...
# DAL  {'fg3': 19, 'orb': 3, 'drb': 25, 'trb': 28, 'a...
# MEM  {'fg3': 22, 'orb': 6, 'drb': 29, 'trb': 35, 'a...
# SAS  {'fg3': 20, 'orb': 6, 'drb': 35, 'trb': 41, 'a...
# HOU  {'fg3': 21, 'orb': 8, 'drb': 30, 'trb': 38, 'a...
# NOP  {'fg3': 30, 'orb': 12, 'drb': 47, 'trb': 59, '...
#
#                                                     SF  \
# PHI  {'fg3': 12, 'orb': 5, 'drb': 29, 'trb': 34, 'a...
# BRK  {'fg3': 25, 'orb': 7, 'drb': 54, 'trb': 61, 'a...
# NYK  {'fg3': 18, 'orb': 4, 'drb': 36, 'trb': 40, 'a...
# TOR  {'fg3': 27, 'orb': 10, 'drb': 42, 'trb': 52, '...
# BOS  {'fg3': 21, 'orb': 12, 'drb': 55, 'trb': 67, '...
# CHI  {'fg3': 11, 'orb': 10, 'drb': 39, 'trb': 49, '...
# CLE  {'fg3': 11, 'orb': 6, 'drb': 31, 'trb': 37, 'a...
# MIL  {'fg3': 8, 'orb': 15, 'drb': 40, 'trb': 55, 'a...
# IND  {'fg3': 17, 'orb': 3, 'drb': 26, 'trb': 29, 'a...
# DET  {'fg3': 8, 'orb': 16, 'drb': 31, 'trb': 47, 'a...
# MIA  {'fg3': 14, 'orb': 11, 'drb': 25, 'trb': 36, '...
# WAS  {'fg3': 8, 'orb': 7, 'drb': 27, 'trb': 34, 'as...
# CHO  {'fg3': 25, 'orb': 13, 'drb': 43, 'trb': 56, '...
# ATL  {'fg3': 13, 'orb': 3, 'drb': 24, 'trb': 27, 'a...
# ORL  {'fg3': 15, 'orb': 8, 'drb': 26, 'trb': 34, 'a...
# UTA  {'fg3': 2, 'orb': 11, 'drb': 25, 'trb': 36, 'a...
# DEN  {'fg3': 12, 'orb': 5, 'drb': 20, 'trb': 25, 'a...
# POR  {'fg3': 17, 'orb': 3, 'drb': 23, 'trb': 26, 'a...
# MIN  {'fg3': 1, 'orb': 2, 'drb': 3, 'trb': 5, 'ast'...
# OKC  {'fg3': 14, 'orb': 7, 'drb': 40, 'trb': 47, 'a...
# GSW  {'fg3': 21, 'orb': 9, 'drb': 32, 'trb': 41, 'a...
# PHO  {'fg3': 15, 'orb': 3, 'drb': 22, 'trb': 25, 'a...
# LAL  {'fg3': 26, 'orb': 7, 'drb': 53, 'trb': 60, 'a...
# SAC  {'fg3': 10, 'orb': 4, 'drb': 29, 'trb': 33, 'a...
# LAC  {'fg3': 19, 'orb': 3, 'drb': 35, 'trb': 38, 'a...
# DAL  {'fg3': 9, 'orb': 1, 'drb': 17, 'trb': 18, 'as...
# MEM  {'fg3': 23, 'orb': 5, 'drb': 35, 'trb': 40, 'a...
# SAS  {'fg3': 6, 'orb': 7, 'drb': 30, 'trb': 37, 'as...
# HOU  {'fg3': 10, 'orb': 10, 'drb': 37, 'trb': 47, '...
# NOP  {'fg3': 12, 'orb': 5, 'drb': 41, 'trb': 46, 'a...
#
#                                                     PF  \
# PHI  {'fg3': 10, 'orb': 5, 'drb': 43, 'trb': 48, 'a...
# BRK  {'fg3': 17, 'orb': 13, 'drb': 83, 'trb': 96, '...
# NYK  {'fg3': 13, 'orb': 10, 'drb': 43, 'trb': 53, '...
# TOR  {'fg3': 5, 'orb': 19, 'drb': 38, 'trb': 57, 'a...
# BOS  {'fg3': 8, 'orb': 10, 'drb': 32, 'trb': 42, 'a...
# CHI  {'fg3': 6, 'orb': 5, 'drb': 15, 'trb': 20, 'as...
# CLE  {'fg3': 14, 'orb': 21, 'drb': 66, 'trb': 87, '...
# MIL  {'fg3': 22, 'orb': 13, 'drb': 56, 'trb': 69, '...
# IND  {'fg3': 12, 'orb': 7, 'drb': 38, 'trb': 45, 'a...
# DET  {'fg3': 15, 'orb': 7, 'drb': 41, 'trb': 48, 'a...
# MIA  {'fg3': 8, 'orb': 11, 'drb': 32, 'trb': 43, 'a...
# WAS  {'fg3': 13, 'orb': 13, 'drb': 66, 'trb': 79, '...
# CHO  {'fg3': 13, 'orb': 12, 'drb': 62, 'trb': 74, '...
# ATL  {'fg3': 15, 'orb': 14, 'drb': 65, 'trb': 79, '...
# ORL  {'fg3': 7, 'orb': 12, 'drb': 31, 'trb': 43, 'a...
# UTA  {'fg3': 13, 'orb': 10, 'drb': 23, 'trb': 33, '...
# DEN  {'fg3': 11, 'orb': 10, 'drb': 41, 'trb': 51, '...
# POR  {'fg3': 17, 'orb': 4, 'drb': 49, 'trb': 53, 'a...
# MIN  {'fg3': 8, 'orb': 17, 'drb': 41, 'trb': 58, 'a...
# OKC  {'fg3': 11, 'orb': 6, 'drb': 35, 'trb': 41, 'a...
# GSW  {'fg3': 6, 'orb': 10, 'drb': 49, 'trb': 59, 'a...
# PHO  {'fg3': 10, 'orb': 2, 'drb': 32, 'trb': 34, 'a...
# LAL  {'fg3': 4, 'orb': 2, 'drb': 5, 'trb': 7, 'ast'...
# SAC  {'fg3': 21, 'orb': 12, 'drb': 48, 'trb': 60, '...
# LAC  {'fg3': 14, 'orb': 6, 'drb': 36, 'trb': 42, 'a...
# DAL  {'fg3': 11, 'orb': 17, 'drb': 39, 'trb': 56, '...
# MEM  {'fg3': 16, 'orb': 2, 'drb': 41, 'trb': 43, 'a...
# SAS  {'fg3': 12, 'orb': 5, 'drb': 27, 'trb': 32, 'a...
# HOU  {'fg3': 2, 'orb': 5, 'drb': 11, 'trb': 16, 'as...
# NOP  {'fg3': 10, 'orb': 10, 'drb': 26, 'trb': 36, '...
#
#                                                      C
# PHI  {'fg3': 6, 'orb': 22, 'drb': 63, 'trb': 85, 'a...
# BRK  {'fg3': 4, 'orb': 6, 'drb': 20, 'trb': 26, 'as...
# NYK  {'fg3': 15, 'orb': 28, 'drb': 83, 'trb': 111, ...
# TOR  {'fg3': 4, 'orb': 31, 'drb': 77, 'trb': 108, '...
# BOS  {'fg3': 11, 'orb': 38, 'drb': 102, 'trb': 140,...
# CHI  {'fg3': 12, 'orb': 14, 'drb': 72, 'trb': 86, '...
# CLE  {'fg3': 2, 'orb': 28, 'drb': 87, 'trb': 115, '...
# MIL  {'fg3': 3, 'orb': 20, 'drb': 31, 'trb': 51, 'a...
# IND  {'fg3': 12, 'orb': 33, 'drb': 93, 'trb': 126, ...
# DET  {'fg3': 2, 'orb': 18, 'drb': 67, 'trb': 85, 'a...
# MIA  {'fg3': 0, 'orb': 19, 'drb': 62, 'trb': 81, 'a...
# WAS  {'fg3': 3, 'orb': 31, 'drb': 47, 'trb': 78, 'a...
# CHO  {'fg3': 4, 'orb': 31, 'drb': 76, 'trb': 107, '...
# ATL  {'fg3': 2, 'orb': 22, 'drb': 69, 'trb': 91, 'a...
# ORL  {'fg3': 18, 'orb': 42, 'drb': 105, 'trb': 147,...
# UTA  {'fg3': 4, 'orb': 18, 'drb': 81, 'trb': 99, 'a...
# DEN  {'fg3': 7, 'orb': 20, 'drb': 76, 'trb': 96, 'a...
# POR  {'fg3': 1, 'orb': 24, 'drb': 82, 'trb': 106, '...
# MIN  {'fg3': 22, 'orb': 25, 'drb': 46, 'trb': 71, '...
# OKC  {'fg3': 6, 'orb': 31, 'drb': 57, 'trb': 88, 'a...
# GSW  {'fg3': 3, 'orb': 15, 'drb': 41, 'trb': 56, 'a...
# PHO  {'fg3': 1, 'orb': 22, 'drb': 63, 'trb': 85, 'a...
# LAL  {'fg3': 3, 'orb': 44, 'drb': 82, 'trb': 126, '...
# SAC  {'fg3': 3, 'orb': 29, 'drb': 95, 'trb': 124, '...
# LAC  {'fg3': 6, 'orb': 23, 'drb': 45, 'trb': 68, 'a...
# DAL  {'fg3': 2, 'orb': 15, 'drb': 54, 'trb': 69, 'a...
# MEM  {'fg3': 1, 'orb': 24, 'drb': 49, 'trb': 73, 'a...
# SAS  {'fg3': 6, 'orb': 36, 'drb': 61, 'trb': 97, 'a...
# HOU  {'fg3': 11, 'orb': 26, 'drb': 62, 'trb': 88, '...
# NOP  {'fg3': 12, 'orb': 33, 'drb': 62, 'trb': 95, '...

# %%
all_stats_df.sort_values(by=['3p'])

# %%
all_stats_df.sort_values(by=['trb'])

# %%
all_stats_df.sort_values(by=['ast'])

# %%
all_stats_df.sort_values(by=['pts'])

# %%
all_stats_df.sort_values(by=['pra'])

# %%
book = get_url(BOOK_URL)

# Each stat
for tbody in book.find_all("tbody", attrs={"data-group":"odds-table--props-0"}):
    # Each player
    for tr in tbody.find_all("tr")[]:
        # 
        for td in tr.find_all("td"):
# Out:
# odds-table--3-pointers-0
# odds-table--assists-0
# odds-table--points-0
# odds-table--points-&-assists-0
# odds-table--points-&-rebounds-0
# odds-table--points,-rebounds,-&-assists-0
# odds-table--rebounds-0

# %%
# Out:
# 'aa'

# %% [raw]
# TODO:
# - Collect all team abbreviations in a dictionary {"abbrev": "team"}
# - Connect to basketballreference.com
# - Retrieve schedule
# - Using schedule, find the box score for each of the games
# - Collect statistics for starters based on the position
#     - Might need to classify positions of players first / lookup
#     - These should include current season performance, and performance in the last X games
# - Collect average statistics of starters for each team
#     - These should include last seasons performance, current season performance, and performance in the last X games
#
# - Based on the resulting data, compare each players statistics against the average performance for a player in their position against the team they are playing
#     - retrieve the schedule of the current day
#     - For each game, for each position, compare a player's statistic to the team statistic to output players that are likely to outperform expectations
#
# - Collect data from Caeser's Sportsbook or Draftkings sportsbook for player props
# - Display the average, P, R, A, 3PM & PRA over last X games, comparing it with the lines and team performance
# - This should ultimately highlight which players to bet on to beat the book
#
# - Run this model every day
# - Following the end of all games for a given day, run a different algorithm to collect the actual performances of the players versus the betting lines, and keep track of how many bets our algorithm predicted right
# - Output the projected money won
